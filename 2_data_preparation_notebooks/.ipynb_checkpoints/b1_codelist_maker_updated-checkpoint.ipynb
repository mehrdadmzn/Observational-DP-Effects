# %% [markdown]
# # Codelists
#
# - Preparing the codelists for phenotype extraction including:
#
#   - Pre-processing
#   - READ2 to CTV3 mapping

# %%
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 500)

# %%
import os
import sys

root_path = os.path.dirname(os.path.abspath(os.path.dirname('__file__')))
sys.path.insert(0, root_path)

# %%
from env.parameters import P

# %%
P.codelist_path

# %%
# Codelist where read2 is different form ctv3
df_read_diff = pd.read_csv(f'''{P.codelist_path}/diff_read2_ctv3_for_codelists.csv''')
df_read_diff = df_read_diff.rename(columns= {"READV2_CODE":"code_clean", "READV3_CODE":"READ3"})

# %%
df_read_diff.head()
# Out:
#   code_clean              READV2_DESC  READ3               TERMV3_DESC
# 0      01...             Top managers  XE0Nq               Top manager
# 1      01...             Top managers  XaBKm       Administrator - top
# 2      013..  Top managers - business  XE0Nr    Top manager - business
# 3      013..  Top managers - business  XaBNP        Business - top men
# 4      013..  Top managers - business  XaBNO  Director - large company

# %%
path = f'''{P.codelist_path}/curated'''

# %% [markdown]
# # Motor Neuron

# %%
df = pd.read_csv(f'''{P.codelist_path}/Motor_Neuron_phenotype_PH62_ver_124_concepts_20231228T125837.csv''')
df.head()
# Out:
#       code                       description  coding_system concept_id  \
# 0  F15y.00  Other anterior horn cell disease  Read codes v2       C852
# 1  F15z.00    Anterior horn cell disease NOS  Read codes v2       C852
# 2  F152z00         Motor neurone disease NOS  Read codes v2       C852
# 3  F15..00        Anterior horn cell disease  Read codes v2       C852
# 4  F152000     Amyotrophic lateral sclerosis  Read codes v2       C852
#
#    concept_version_id                         concept_name phenotype_id  \
# 0                2843  Motor neuron disease - Primary care         PH62
# 1                2843  Motor neuron disease - Primary care         PH62
# 2                2843  Motor neuron disease - Primary care         PH62
# 3                2843  Motor neuron disease - Primary care         PH62
# 4                2843  Motor neuron disease - Primary care         PH62
#
#    phenotype_version_id        phenotype_name  \
# 0                   124  Motor neuron disease
# ...

# %%
df.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# ICD10 codes       1
# Med codes        12
# Read codes v2    12
# Name: code, dtype: int64

# %%
df["vocab"] = df["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes":"SNOMED", "Read codes v2":"Read2"})

# %%
df.groupby(by="vocab").agg("count")["code"]
# Out:
# vocab
# ICD10     1
# Read2    12
# Name: code, dtype: int64

# %%
df["code_clean"]  =df["code"]
df.loc[df["vocab"]=="ICD10", "code_clean"] = df["code_clean"].str.replace(".","")
    #.str.lower()

# %%
df["pheno_name"] = "motor_neuron"
df["info"] = "PH62"

# %%
df_sel =df[["pheno_name","code_clean", "vocab","description",  "info"]]
df_sel.head()
# Out:
#      pheno_name code_clean  vocab                       description  info
# 0  motor_neuron    F15y.00  Read2  Other anterior horn cell disease  PH62
# 1  motor_neuron    F15z.00  Read2    Anterior horn cell disease NOS  PH62
# 2  motor_neuron    F152z00  Read2         Motor neurone disease NOS  PH62
# 3  motor_neuron    F15..00  Read2        Anterior horn cell disease  PH62
# 4  motor_neuron    F152000  Read2     Amyotrophic lateral sclerosis  PH62

# %%
df_sel = df_sel[(df_sel["vocab"]=="Read2") | (df_sel["vocab"]=="ICD10")]
df_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    12
# ICD10     1
# Name: count, dtype: int64

# %%
# any CTV3?

df_read_new =  pd.merge(df_sel[(df_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
# Empty DataFrame
# Columns: [pheno_name, vocab, description, info, READV2_DESC, code_clean, TERMV3_DESC]
# Index: []

# %%
df_sel = df_sel[['pheno_name', 'code_clean', 'vocab', 'description', 'info']]

# %%
df_sel.head()
# Out:
#      pheno_name code_clean  vocab                       description  info
# 0  motor_neuron    F15y.00  Read2  Other anterior horn cell disease  PH62
# 1  motor_neuron    F15z.00  Read2    Anterior horn cell disease NOS  PH62
# 2  motor_neuron    F152z00  Read2         Motor neurone disease NOS  PH62
# 3  motor_neuron    F15..00  Read2        Anterior horn cell disease  PH62
# 4  motor_neuron    F152000  Read2     Amyotrophic lateral sclerosis  PH62

# %%
df_sel.to_csv(f'''{path}/motor_neuron.csv''', index=False)

# %% [markdown]
# # Parkinson

# %%
# codelist
df = pd.read_csv(f'''{P.codelist_path}/Parkinson_phenotype_PH77_ver_154_concepts_20231228T125909.csv''')
df.head()
# Out:
#       code                                   description  coding_system  \
# 0  Eu02300            [X]Dementia in Parkinson's disease  Read codes v2
# 1  147F.00                History of Parkinson's disease  Read codes v2
# 2  F12z.00                       Parkinson's disease NOS  Read codes v2
# 3  F11x900  Cerebral degeneration in Parkinson's disease  Read codes v2
# 4  F12..00                           Parkinson's disease  Read codes v2
#
#   concept_id  concept_version_id                        concept_name  \
# 0       C896                2931  Parkinson's disease - Primary care
# 1       C896                2931  Parkinson's disease - Primary care
# 2       C896                2931  Parkinson's disease - Primary care
# 3       C896                2931  Parkinson's disease - Primary care
# 4       C896                2931  Parkinson's disease - Primary care
#
#   phenotype_id  phenotype_version_id       phenotype_name  \
# ...

# %%
df.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# ICD10 codes      2
# Med codes        6
# Read codes v2    6
# Name: code, dtype: int64

# %%
df["vocab"] = df["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes":"SNOMED", "Read codes v2":"Read2"})

# %%
df.groupby(by="vocab").agg("count")["code"]
# Out:
# vocab
# ICD10    2
# Read2    6
# Name: code, dtype: int64

# %%
df["code_clean"]  =df["code"]
df.loc[df["vocab"]=="ICD10", "code_clean"] = df["code_clean"].str.replace(".","")
    #.str.lower()

# %%
df["pheno_name"] = "parkinson"
df["info"] = "PH77"

# %%
df_sel =df[["pheno_name","code_clean", "vocab","description",  "info"]]
df_sel.head()
# Out:
#   pheno_name code_clean  vocab                                   description  \
# 0  parkinson    Eu02300  Read2            [X]Dementia in Parkinson's disease
# 1  parkinson    147F.00  Read2                History of Parkinson's disease
# 2  parkinson    F12z.00  Read2                       Parkinson's disease NOS
# 3  parkinson    F11x900  Read2  Cerebral degeneration in Parkinson's disease
# 4  parkinson    F12..00  Read2                           Parkinson's disease
#
#    info
# 0  PH77
# 1  PH77
# 2  PH77
# 3  PH77
# 4  PH77

# %%
df_sel = df_sel[(df_sel["vocab"]=="Read2") | (df_sel["vocab"]=="ICD10")]
df_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    6
# ICD10    2
# Name: count, dtype: int64

# %%
# any CTV3?

df_read_new =  pd.merge(df_sel[(df_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
# Empty DataFrame
# Columns: [pheno_name, vocab, description, info, READV2_DESC, code_clean, TERMV3_DESC]
# Index: []

# %%
df_sel = df_sel[['pheno_name', 'code_clean', 'vocab', 'description', 'info']]

# %%
df_sel.to_csv(f'''{path}/parkinson.csv''', index=False)

# %% [markdown]
# # AAA

# %%
# codelist
df = pd.read_csv(f'''{P.codelist_path}/abdominal_aortic_aneurysm_phenotype_PH34_ver_68_concepts_20240309T212846.csv''')
df.head()
# Out:
#       code                                        description  coding_system  \
# 0  7A11000  Emerg repl aneurysm bifurc aorta by anast aort...  Read codes v2
# 1  14AE.00                               H/O: aortic aneurysm  Read codes v2
# 2  G714.11  AAA - Abdominal aortic aneurysm without mentio...  Read codes v2
# 3  7A13z00  Emergency replacement of aneurysmal segment of...  Read codes v2
# 4  7A13400  Emerg replace aneurysm abdom aorta by anast ao...  Read codes v2
#
#   concept_id  concept_version_id                              concept_name  \
# 0       C783                2705  Abdominal aortic aneurysm - Primary care
# 1       C783                2705  Abdominal aortic aneurysm - Primary care
# 2       C783                2705  Abdominal aortic aneurysm - Primary care
# 3       C783                2705  Abdominal aortic aneurysm - Primary care
# 4       C783                2705  Abdominal aortic aneurysm - Primary care
#
# ...

# %%
df.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# ICD10 codes       3
# Med codes        15
# Read codes v2    15
# Name: code, dtype: int64

# %%
df["vocab"] = df["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes":"SNOMED", "Read codes v2":"Read2"})

# %%
df.groupby(by="vocab").agg("count")["code"]
# Out:
# vocab
# ICD10     3
# Read2    15
# Name: code, dtype: int64

# %%
df["code_clean"]  =df["code"]
df.loc[df["vocab"]=="ICD10", "code_clean"] = df["code_clean"].str.replace(".","")
    #.str.lower()

# %%
df["pheno_name"] = "aaa"
df["info"] = "PH34"

# %%
df_sel =df[["pheno_name","code_clean", "vocab","description",  "info"]]
df_sel.head()
# Out:
#   pheno_name code_clean  vocab  \
# 0        aaa    7A11000  Read2
# 1        aaa    14AE.00  Read2
# 2        aaa    G714.11  Read2
# 3        aaa    7A13z00  Read2
# 4        aaa    7A13400  Read2
#
#                                          description  info
# 0  Emerg repl aneurysm bifurc aorta by anast aort...  PH34
# 1                               H/O: aortic aneurysm  PH34
# 2  AAA - Abdominal aortic aneurysm without mentio...  PH34
# 3  Emergency replacement of aneurysmal segment of...  PH34
# 4  Emerg replace aneurysm abdom aorta by anast ao...  PH34

# %%
df_sel = df_sel[(df_sel["vocab"]=="Read2") | (df_sel["vocab"]=="ICD10")]
df_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    15
# ICD10     3
# Name: count, dtype: int64

# %%
# any CTV3?

df_read_new =  pd.merge(df_sel[(df_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
# Empty DataFrame
# Columns: [pheno_name, vocab, description, info, READV2_DESC, code_clean, TERMV3_DESC]
# Index: []

# %%
df_sel.to_csv(f'''{path}/aaa.csv''', index=False)

# %% [markdown]
# # Anxiety

# %%
df = pd.read_csv(f'''{P.codelist_path}/Anxiety_phenotype_PH1113_ver_2453_concepts_20240217T235545.csv''')
df.head()
# Out:
#     code                                        description  coding_system  \
# 0  E2000                          anxiety state unspecified  Read codes v2
# 1  Eu41z  [x]anxiety disord unspecified | [x]anxiety dis...  Read codes v2
# 2  Eu932  [x]social anx dis childhood | [x]social anxiet...  Read codes v2
# 3  E2021                     agoraphobia with panic attacks  Read codes v2
# 4  E2D00  child/adolesc.overanxious.dis. | childhood and...  Read codes v2
#
#   concept_id  concept_version_id                          concept_name  \
# 0      C2921               10162  Anxiety Diagnosis (Core)- Read Codes
# 1      C2921               10162  Anxiety Diagnosis (Core)- Read Codes
# 2      C2921               10162  Anxiety Diagnosis (Core)- Read Codes
# 3      C2921               10162  Anxiety Diagnosis (Core)- Read Codes
# 4      C2921               10162  Anxiety Diagnosis (Core)- Read Codes
#
#   phenotype_id  phenotype_version_id      phenotype_name  code_attributes
# ...

# %%
df.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# ICD10 codes       22
# Read codes v2    335
# Name: code, dtype: int64

# %%
df["vocab"] = df["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes":"SNOMED", "Read codes v2":"Read2"})

# %%
df.groupby(by="vocab").agg("count")["code"]
# Out:
# vocab
# ICD10     22
# Read2    335
# Name: code, dtype: int64

# %%
df["code_clean"]  =df["code"]
df.loc[df["vocab"]=="ICD10", "code_clean"] = df["code_clean"].str.replace(".","")
    #.str.lower()

# %%
df["pheno_name"] = "Anxiety"
df["info"] = "PH1113_v2453"

# %%
df_sel =df[["pheno_name","code_clean", "vocab","description",  "info"]]
df_sel.head()
# Out:
#   pheno_name code_clean  vocab  \
# 0    Anxiety      E2000  Read2
# 1    Anxiety      Eu41z  Read2
# 2    Anxiety      Eu932  Read2
# 3    Anxiety      E2021  Read2
# 4    Anxiety      E2D00  Read2
#
#                                          description          info
# 0                          anxiety state unspecified  PH1113_v2453
# 1  [x]anxiety disord unspecified | [x]anxiety dis...  PH1113_v2453
# 2  [x]social anx dis childhood | [x]social anxiet...  PH1113_v2453
# 3                     agoraphobia with panic attacks  PH1113_v2453
# 4  child/adolesc.overanxious.dis. | childhood and...  PH1113_v2453

# %%
df_sel = df_sel[(df_sel["vocab"]=="Read2") | (df_sel["vocab"]=="ICD10")]
df_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    335
# ICD10     22
# Name: count, dtype: int64

# %%
# any CTV3?

df_read_new =  pd.merge(df_sel[(df_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
#   pheno_name  vocab                                        description  \
# 0    Anxiety  Read3  [x]anxiety disord unspecified | [x]anxiety dis...
# 1    Anxiety  Read3  [x]social anx dis childhood | [x]social anxiet...
# 2    Anxiety  Read3  [x]social anx dis childhood | [x]social anxiet...
# 3    Anxiety  Read3  [x]social anx dis childhood | [x]social anxiet...
# 4    Anxiety  Read3  [x]social anx dis childhood | [x]social anxiet...
#
#            info                              READV2_DESC code_clean  \
# 0  PH1113_v2453         [X]Anxiety disorder, unspecified      E200.
# 1  PH1113_v2453  [X]Social anxiety disorder of childhood      XE1aD
# 2  PH1113_v2453  [X]Social anxiety disorder of childhood      XE1aD
# 3  PH1113_v2453  [X]Social anxiety disorder of childhood      XE1aD
# 4  PH1113_v2453  [X]Social anxiety disorder of childhood      XE1aD
#
#                          TERMV3_DESC
# 0                   Anxiety disorder
# 1  Childhood social anxiety disorder
# ...

# %%
df_read_new = df_read_new[['pheno_name', 'code_clean', 'vocab', 'description', 'info']]

# %%
df_read_new.shape
# Out:
# (78, 5)

# %%
df_sel_final = pd.concat([df_sel, df_read_new])

# %%
df_sel_final.head()
# Out:
#   pheno_name code_clean  vocab  \
# 0    Anxiety      E2000  Read2
# 1    Anxiety      Eu41z  Read2
# 2    Anxiety      Eu932  Read2
# 3    Anxiety      E2021  Read2
# 4    Anxiety      E2D00  Read2
#
#                                          description          info
# 0                          anxiety state unspecified  PH1113_v2453
# 1  [x]anxiety disord unspecified | [x]anxiety dis...  PH1113_v2453
# 2  [x]social anx dis childhood | [x]social anxiet...  PH1113_v2453
# 3                     agoraphobia with panic attacks  PH1113_v2453
# 4  child/adolesc.overanxious.dis. | childhood and...  PH1113_v2453

# %%
df_sel_final['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    335
# Read3     78
# ICD10     22
# Name: count, dtype: int64

# %%
df_sel_final.to_csv(f'''{path}/anxiety_updated.csv''', index=False)

# %% [markdown]
# # AMI

# %%
df = pd.read_csv(f'''{P.codelist_path}/AMI_phenotype_PH949_ver_2127_concepts_20231109T105016.csv''')
df.head()
# Out:
#         code                                        description  \
# 0        I23  Certain current complications following acute ...
# 1        I21                        Acute myocardial infarction
# 2        I22                   Subsequent myocardial infarction
# 3   70422006                    Acute subendocardial infarction
# 4  703209002  Subsequent ST segment elevation myocardial inf...
#
#       coding_system concept_id  concept_version_id  \
# 0       ICD10 codes      C2739                7260
# 1       ICD10 codes      C2739                7260
# 2       ICD10 codes      C2739                7260
# 3  SNOMED  CT codes      C2740                7261
# 4  SNOMED  CT codes      C2740                7261
#
#                                         concept_name phenotype_id  \
# 0  CCU002_01 Acute myocardial infarction - Phenot...        PH949
# 1  CCU002_01 Acute myocardial infarction - Phenot...        PH949
# 2  CCU002_01 Acute myocardial infarction - Phenot...        PH949
# ...

# %%
# Test

# %%
df.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# ICD10 codes          5
# Read codes v2       60
# SNOMED  CT codes    75
# Name: code, dtype: int64

# %%
df["vocab"] = df["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes":"SNOMED", "Read codes v2":"Read2"})

# %%
df.groupby(by="vocab").agg("count")["code"]
# Out:
# vocab
# ICD10      5
# Read2     60
# SNOMED    75
# Name: code, dtype: int64

# %%
df["code_clean"]  =df["code"]
df.loc[df["vocab"]=="ICD10", "code_clean"] = df["code_clean"].str.replace(".","")
    #.str.lower()

# %%
df.head()
# Out:
#         code                                        description  \
# 0        I23  Certain current complications following acute ...
# 1        I21                        Acute myocardial infarction
# 2        I22                   Subsequent myocardial infarction
# 3   70422006                    Acute subendocardial infarction
# 4  703209002  Subsequent ST segment elevation myocardial inf...
#
#       coding_system concept_id  concept_version_id  \
# 0       ICD10 codes      C2739                7260
# 1       ICD10 codes      C2739                7260
# 2       ICD10 codes      C2739                7260
# 3  SNOMED  CT codes      C2740                7261
# 4  SNOMED  CT codes      C2740                7261
#
#                                         concept_name phenotype_id  \
# 0  CCU002_01 Acute myocardial infarction - Phenot...        PH949
# 1  CCU002_01 Acute myocardial infarction - Phenot...        PH949
# 2  CCU002_01 Acute myocardial infarction - Phenot...        PH949
# ...

# %%
df["pheno_name"] = "AMI"
df["info"] = "PH949_v2127"

# %%
df['vocab'].value_counts(dropna=False)
# Out:
# vocab
# SNOMED    75
# Read2     60
# ICD10      5
# Name: count, dtype: int64

# %%
df_sel =df[["pheno_name","code_clean", "vocab","description",  "info"]]
df_sel.head()
# Out:
#   pheno_name code_clean   vocab  \
# 0        AMI        I23   ICD10
# 1        AMI        I21   ICD10
# 2        AMI        I22   ICD10
# 3        AMI   70422006  SNOMED
# 4        AMI  703209002  SNOMED
#
#                                          description         info
# 0  Certain current complications following acute ...  PH949_v2127
# 1                        Acute myocardial infarction  PH949_v2127
# 2                   Subsequent myocardial infarction  PH949_v2127
# 3                    Acute subendocardial infarction  PH949_v2127
# 4  Subsequent ST segment elevation myocardial inf...  PH949_v2127

# %%
df_sel = df_sel[(df_sel["vocab"]=="Read2") | (df_sel["vocab"]=="ICD10")]
df_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    60
# ICD10     5
# Name: count, dtype: int64

# %%
# any CTV3?

df_read_new =  pd.merge(df_sel[(df_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
#   pheno_name  vocab                                        description  \
# 0        AMI  Read3  Acute transmural myocardial infarction of unsp...
# 1        AMI  Read3  Acute non-Q wave infarction                   ...
# 2        AMI  Read3  Diab mellit insulin-glucose infus acute myocar...
# 3        AMI  Read3  Postoperative subendocardial myocardial infarc...
# 4        AMI  Read3  Old myocardial infarction                     ...
#
#           info                                        READV2_DESC code_clean  \
# 0  PH949_v2127  Acute transmural myocardial infarction of unsp...      Gyu34
# 1  PH949_v2127                        Acute non-Q wave infarction      XaAzi
# 2  PH949_v2127  Diabetes mellitus insulin-glucose infusion in ...      XaFx7
# 3  PH949_v2127  Postoperative subendocardial myocardial infarc...      XaD2h
# 4  PH949_v2127                          Old myocardial infarction      XE2aA
#
#                                          TERMV3_DESC
# ...

# %%
df_read_new = df_read_new[['pheno_name', 'code_clean', 'vocab', 'description', 'info']]

# %%
df_read_new.shape
# Out:
# (33, 5)

# %%
df_sel_final = pd.concat([df_sel, df_read_new])

# %%
df_sel_final.head()
# Out:
#    pheno_name code_clean  vocab  \
# 0         AMI        I23  ICD10
# 1         AMI        I21  ICD10
# 2         AMI        I22  ICD10
# 78        AMI       I241  ICD10
# 79        AMI       I252  ICD10
#
#                                           description         info
# 0   Certain current complications following acute ...  PH949_v2127
# 1                         Acute myocardial infarction  PH949_v2127
# 2                    Subsequent myocardial infarction  PH949_v2127
# 78                                Dressler's syndrome  PH949_v2127
# 79                          Old myocardial infarction  PH949_v2127

# %%
df_sel_final['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    60
# Read3    33
# ICD10     5
# Name: count, dtype: int64

# %%
df_sel_final.to_csv(f'''{path}/ami_updated.csv''', index=False)

# %%
test = pd.read_csv(f'''{path}/ami_updated.csv''')
test.head()
# Out:
#   pheno_name code_clean  vocab  \
# 0        AMI        I23  ICD10
# 1        AMI        I21  ICD10
# 2        AMI        I22  ICD10
# 3        AMI       I241  ICD10
# 4        AMI       I252  ICD10
#
#                                          description         info
# 0  Certain current complications following acute ...  PH949_v2127
# 1                        Acute myocardial infarction  PH949_v2127
# 2                   Subsequent myocardial infarction  PH949_v2127
# 3                                Dressler's syndrome  PH949_v2127
# 4                          Old myocardial infarction  PH949_v2127

# %% [markdown]
# # Asthma

# %%
df = pd.read_csv(f'''{P.codelist_path}/asthma_phenotype_PH12_ver_24_concepts_20231225T224912.csv''')
df.head()
# Out:
#       code                                        description  coding_system  \
# 0  663d.00  Emergency asthma admission since last appointment  Read codes v2
# 1  1788.00                          Asthma trigger - cold air  Read codes v2
# 2  663N000                        Asthma causing night waking  Read codes v2
# 3  679J100    Health education - structured asthma discussion  Read codes v2
# 4  8H2P.00                        Emergency admission, asthma  Read codes v2
#
#   concept_id  concept_version_id           concept_name phenotype_id  \
# 0       C733                2605  Asthma - Primary care         PH12
# 1       C733                2605  Asthma - Primary care         PH12
# 2       C733                2605  Asthma - Primary care         PH12
# 3       C733                2605  Asthma - Primary care         PH12
# 4       C733                2605  Asthma - Primary care         PH12
#
#    phenotype_version_id phenotype_name  \
# 0                    24         Asthma
# ...

# %%
df.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# ICD10 codes           4
# ICD11 codes           3
# Read codes v2       165
# SNOMED  CT codes    150
# UKBioBank codes       1
# Name: code, dtype: int64

# %%
df["vocab"] = df["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes":"SNOMED", "Read codes v2":"Read2"})

# %%
df["code_clean"]  =df["code"]
df.loc[df["vocab"]=="ICD10", "code_clean"] = df["code_clean"].str.replace(".","")
df.head()
# Out:
#       code                                        description  coding_system  \
# 0  663d.00  Emergency asthma admission since last appointment  Read codes v2
# 1  1788.00                          Asthma trigger - cold air  Read codes v2
# 2  663N000                        Asthma causing night waking  Read codes v2
# 3  679J100    Health education - structured asthma discussion  Read codes v2
# 4  8H2P.00                        Emergency admission, asthma  Read codes v2
#
#   concept_id  concept_version_id           concept_name phenotype_id  \
# 0       C733                2605  Asthma - Primary care         PH12
# 1       C733                2605  Asthma - Primary care         PH12
# 2       C733                2605  Asthma - Primary care         PH12
# 3       C733                2605  Asthma - Primary care         PH12
# 4       C733                2605  Asthma - Primary care         PH12
#
#    phenotype_version_id phenotype_name  \
# 0                    24         Asthma
# ...

# %%
df["pheno_name"] = "asthma"
df["info"] = "PH12_v24"

# %%
df['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2     165
# SNOMED    150
# NaN         4
# ICD10       4
# Name: count, dtype: int64

# %%
df_sel =df[["pheno_name","code_clean", "vocab", "description", "info"]]

df_sel = df_sel[(df_sel["vocab"]=="Read2") | (df_sel["vocab"]=="ICD10")]
df_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    165
# ICD10      4
# Name: count, dtype: int64

# %%
# any CTV3?

df_read_new =  pd.merge(df_sel[(df_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
# Empty DataFrame
# Columns: [pheno_name, vocab, description, info, READV2_DESC, code_clean, TERMV3_DESC]
# Index: []

# %%
df_sel.to_csv(f'''{path}/asthma.csv''', index=False)

# %% [markdown]
# # Cancer

# %%
df = pd.read_csv(f'''{P.codelist_path}/Cancer_phenotype_PH960_ver_2138_concepts_20231115T192850.csv''')
df.head()
# Out:
#   code                                        description coding_system  \
# 0  C10               C10 Malignant neoplasm of oropharynx   ICD10 codes
# 1  C38  C38 Malignant neoplasm of heart, mediastinum a...   ICD10 codes
# 2  C62                   C62 Malignant neoplasm of testis   ICD10 codes
# 3  C32                   C32 Malignant neoplasm of larynx   ICD10 codes
# 4  C56                    C56 Malignant neoplasm of ovary   ICD10 codes
#
#   concept_id  concept_version_id  \
# 0      C2765                7286
# 1      C2765                7286
# 2      C2765                7286
# 3      C2765                7286
# 4      C2765                7286
#
#                                         concept_name phenotype_id  \
# 0  CCU002_01 Cancer - Phenotypes - England hospit...        PH960
# 1  CCU002_01 Cancer - Phenotypes - England hospit...        PH960
# 2  CCU002_01 Cancer - Phenotypes - England hospit...        PH960
# ...

# %%
df.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# ICD10 codes           70
# Read codes v2       1667
# SNOMED  CT codes    1918
# Name: code, dtype: int64

# %%
df["vocab"] = df["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes":"SNOMED", "Read codes v2":"Read2"})

# %%
df["code_clean"]  =df["code"]
df.loc[df["vocab"]=="ICD10", "code_clean"] = df["code_clean"].str.replace(".","")
    #.str.lower()

# %%
df["pheno_name"] = "Cancer"
df["info"] = "PH960_v2138"

# %%
df['vocab'].value_counts(dropna=False)
# Out:
# vocab
# SNOMED    1918
# Read2     1667
# ICD10       70
# Name: count, dtype: int64

# %%
df_sel =df[["pheno_name","code_clean", "vocab", "description", "info"]]
df_sel.head()
# Out:
#   pheno_name code_clean  vocab  \
# 0     Cancer        C10  ICD10
# 1     Cancer        C38  ICD10
# 2     Cancer        C62  ICD10
# 3     Cancer        C32  ICD10
# 4     Cancer        C56  ICD10
#
#                                          description         info
# 0               C10 Malignant neoplasm of oropharynx  PH960_v2138
# 1  C38 Malignant neoplasm of heart, mediastinum a...  PH960_v2138
# 2                   C62 Malignant neoplasm of testis  PH960_v2138
# 3                   C32 Malignant neoplasm of larynx  PH960_v2138
# 4                    C56 Malignant neoplasm of ovary  PH960_v2138

# %%
df_sel = df_sel[(df_sel["vocab"]=="Read2") | (df_sel["vocab"]=="ICD10")]
df_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    1667
# ICD10      70
# Name: count, dtype: int64

# %%
# any CTV3?

df_read_new =  pd.merge(df_sel[(df_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
#   pheno_name  vocab                                        description  \
# 0     Cancer  Read3  Fast track referral for suspected childrens tu...
# 1     Cancer  Read3  Malignant neoplasm of palatopharyngeal arch   ...
# 2     Cancer  Read3  Malignant neoplasm of palatopharyngeal arch   ...
# 3     Cancer  Read3  Malignant neoplasm of canthus                 ...
# 4     Cancer  Read3  Malignant neoplasm of lip unspecified, buccal ...
#
#           info                                        READV2_DESC code_clean  \
# 0  PH960_v2138  Fast track referral for suspected childrens tu...      XaMeD
# 1  PH960_v2138        Malignant neoplasm of palatopharyngeal arch      B062.
# 2  PH960_v2138        Malignant neoplasm of palatopharyngeal arch      B062.
# 3  PH960_v2138                      Malignant neoplasm of canthus      XaCKx
# 4  PH960_v2138  Malignant neoplasm of lip unspecified, buccal ...      B0042
#
#                                          TERMV3_DESC
# ...

# %%
df_read_new = df_read_new[['pheno_name', 'code_clean', 'vocab', 'description', 'info']]

# %%
df_read_new.shape
# Out:
# (410, 5)

# %%
df_sel_final = pd.concat([df_sel, df_read_new])

# %%
df_sel_final.head()
# Out:
#   pheno_name code_clean  vocab  \
# 0     Cancer        C10  ICD10
# 1     Cancer        C38  ICD10
# 2     Cancer        C62  ICD10
# 3     Cancer        C32  ICD10
# 4     Cancer        C56  ICD10
#
#                                          description         info
# 0               C10 Malignant neoplasm of oropharynx  PH960_v2138
# 1  C38 Malignant neoplasm of heart, mediastinum a...  PH960_v2138
# 2                   C62 Malignant neoplasm of testis  PH960_v2138
# 3                   C32 Malignant neoplasm of larynx  PH960_v2138
# 4                    C56 Malignant neoplasm of ovary  PH960_v2138

# %%
df_sel_final['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    1667
# Read3     410
# ICD10      70
# Name: count, dtype: int64

# %%
df_sel_final.to_csv(f'''{path}/cancer_updated.csv''', index=False)

# %% [markdown]
# # Cardiomyopathy

# %%
df = pd.read_csv(f'''{P.codelist_path}/Cardiomyopathy_phenotype_PH961_ver_2139_concepts_20231109T110043.csv''')
df.head()
# Out:
#     code                                      description coding_system  \
# 0  O90.3                 Cardiomyopathy in the puerperium   ICD10 codes
# 1    I43  Cardiomyopathy in diseases classified elsewhere   ICD10 codes
# 2  I42.5                 Other restrictive cardiomyopathy   ICD10 codes
# 3  I25.5                         Ischaemic cardiomyopathy   ICD10 codes
# 4  I42.0                           Dilated cardiomyopathy   ICD10 codes
#
#   concept_id  concept_version_id  \
# 0      C2769                7290
# 1      C2769                7290
# 2      C2769                7290
# 3      C2769                7290
# 4      C2769                7290
#
#                                         concept_name phenotype_id  \
# 0  CCU002_01 Cardiomyopathy - Phenotypes - Englan...        PH961
# 1  CCU002_01 Cardiomyopathy - Phenotypes - Englan...        PH961
# 2  CCU002_01 Cardiomyopathy - Phenotypes - Englan...        PH961
# ...

# %%
df.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# ICD10 codes          9
# Read codes v2       31
# SNOMED  CT codes     3
# Name: code, dtype: int64

# %%
df["vocab"] = df["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes":"SNOMED", "Read codes v2":"Read2"})
df["code_clean"]  =df["code"]
df.loc[df["vocab"]=="ICD10", "code_clean"] = df["code_clean"].str.replace(".","")
df["pheno_name"] = "Cardiomyopathy"
df["info"] = "PH961_v2139"
df['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2     31
# ICD10      9
# SNOMED     3
# Name: count, dtype: int64

# %%
df_sel =df[["pheno_name","code_clean", "vocab", "description","info"]]
df_sel.head()
# Out:
#        pheno_name code_clean  vocab  \
# 0  Cardiomyopathy       O903  ICD10
# 1  Cardiomyopathy        I43  ICD10
# 2  Cardiomyopathy       I425  ICD10
# 3  Cardiomyopathy       I255  ICD10
# 4  Cardiomyopathy       I420  ICD10
#
#                                        description         info
# 0                 Cardiomyopathy in the puerperium  PH961_v2139
# 1  Cardiomyopathy in diseases classified elsewhere  PH961_v2139
# 2                 Other restrictive cardiomyopathy  PH961_v2139
# 3                         Ischaemic cardiomyopathy  PH961_v2139
# 4                           Dilated cardiomyopathy  PH961_v2139

# %%
df_sel = df_sel[(df_sel["vocab"]=="Read2") | (df_sel["vocab"]=="ICD10")]
df_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    31
# ICD10     9
# Name: count, dtype: int64

# %%
# any CTV3?

df_read_new =  pd.merge(df_sel[(df_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
#        pheno_name  vocab                                        description  \
# 0  Cardiomyopathy  Read3  Tachycardiomyopathy                           ...
# 1  Cardiomyopathy  Read3  Tachycardiomyopathy                           ...
# 2  Cardiomyopathy  Read3  Secondary cardiomyopathy NOS                  ...
# 3  Cardiomyopathy  Read3  Secondary cardiomyopathy NOS                  ...
# 4  Cardiomyopathy  Read3  Amyloid cardiomyopathy                        ...
#
#           info                   READV2_DESC code_clean  \
# 0  PH961_v2139           Tachycardiomyopathy      XaXNg
# 1  PH961_v2139           Tachycardiomyopathy      XaXNg
# 2  PH961_v2139  Secondary cardiomyopathy NOS      XE0V1
# 3  PH961_v2139  Secondary cardiomyopathy NOS      X201Z
# 4  PH961_v2139        Amyloid cardiomyopathy      XaZcx
#
#                           TERMV3_DESC
# 0                 Tachycardiomyopathy
# 1  Tachycardia-induced cardiomyopathy
# 2        Secondary cardiomyopathy NOS
# ...

# %%
df_read_new = df_read_new[['pheno_name', 'code_clean', 'vocab', 'description', 'info']]

# %%
df_read_new.shape
# Out:
# (16, 5)

# %%
df_sel_final = pd.concat([df_sel, df_read_new])

# %%
df_sel_final['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    31
# Read3    16
# ICD10     9
# Name: count, dtype: int64

# %%
df_sel_final.to_csv(f'''{path}/cardiomyopathy_updated.csv''', index=False)

# %% [markdown]
# # COPD

# %%
df = pd.read_csv(f'''{P.codelist_path}/COPD_phenotype_PH951_ver_2129_concepts_20231115T193027.csv''')
df.head()
# Out:
#   code                                   description coding_system concept_id  \
# 0  J42                Unspecified chronic bronchitis   ICD10 codes      C2746
# 1  J41    Simple and mucopurulent chronic bronchitis   ICD10 codes      C2746
# 2  J40  Bronchitis not specified as acute or chronic   ICD10 codes      C2746
# 3  J44   Other chronic obstructive pulmonary disease   ICD10 codes      C2746
# 4  J43                                     Emphysema   ICD10 codes      C2746
#
#    concept_version_id                                       concept_name  \
# 0                7267  CCU002_01 Chronic obstructive pulmonary diseas...
# 1                7267  CCU002_01 Chronic obstructive pulmonary diseas...
# 2                7267  CCU002_01 Chronic obstructive pulmonary diseas...
# 3                7267  CCU002_01 Chronic obstructive pulmonary diseas...
# 4                7267  CCU002_01 Chronic obstructive pulmonary diseas...
#
#   phenotype_id  phenotype_version_id  \
# ...

# %%
df.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# ICD10 codes          5
# Read codes v2       50
# SNOMED  CT codes    41
# Name: code, dtype: int64

# %%
df["vocab"] = df["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes":"SNOMED", "Read codes v2":"Read2"})
df["code_clean"]  =df["code"]
df.loc[df["vocab"]=="ICD10", "code_clean"] = df["code_clean"].str.replace(".","")
df["pheno_name"] = "COPD"
df["info"] = "PH951_v2129"
df['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2     50
# SNOMED    41
# ICD10      5
# Name: count, dtype: int64

# %%
df_sel =df[["pheno_name","code_clean", "vocab", "description","info"]]
df_sel.head()
# Out:
#   pheno_name code_clean  vocab                                   description  \
# 0       COPD        J42  ICD10                Unspecified chronic bronchitis
# 1       COPD        J41  ICD10    Simple and mucopurulent chronic bronchitis
# 2       COPD        J40  ICD10  Bronchitis not specified as acute or chronic
# 3       COPD        J44  ICD10   Other chronic obstructive pulmonary disease
# 4       COPD        J43  ICD10                                     Emphysema
#
#           info
# 0  PH951_v2129
# 1  PH951_v2129
# 2  PH951_v2129
# 3  PH951_v2129
# 4  PH951_v2129

# %%
df_sel = df_sel[(df_sel["vocab"]=="Read2") | (df_sel["vocab"]=="ICD10")]
df_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    50
# ICD10     5
# Name: count, dtype: int64

# %%
# any CTV3?

df_read_new =  pd.merge(df_sel[(df_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
#   pheno_name  vocab                                        description  \
# 0       COPD  Read3  Eosinophilic bronchitis                       ...
# 1       COPD  Read3  History of chronic obstructive pulmonary disea...
# 2       COPD  Read3  History of chronic obstructive pulmonary disea...
# 3       COPD  Read3  History of chronic obstructive pulmonary disea...
# 4       COPD  Read3  History of chronic obstructive pulmonary disea...
#
#           info                     READV2_DESC code_clean  \
# 0  PH951_v2129         Eosinophilic bronchitis      Xaa7C
# 1  PH951_v2129  H/O: chr.obstr. airway disease      XE2Pp
# 2  PH951_v2129  H/O: chr.obstr. airway disease      XE2Pp
# 3  PH951_v2129  H/O: chr.obstr. airway disease      XM1R4
# 4  PH951_v2129  H/O: chr.obstr. airway disease      XE2Pp
#
#                                         TERMV3_DESC
# 0                           Eosinophilic bronchitis
# 1                                               NaN
# ...

# %%
df_read_new = df_read_new[['pheno_name', 'code_clean', 'vocab', 'description', 'info']]
df_read_new.shape
# Out:
# (24, 5)

# %%
df_sel_final = pd.concat([df_sel, df_read_new])
df_sel_final.head()
# Out:
#   pheno_name code_clean  vocab                                   description  \
# 0       COPD        J42  ICD10                Unspecified chronic bronchitis
# 1       COPD        J41  ICD10    Simple and mucopurulent chronic bronchitis
# 2       COPD        J40  ICD10  Bronchitis not specified as acute or chronic
# 3       COPD        J44  ICD10   Other chronic obstructive pulmonary disease
# 4       COPD        J43  ICD10                                     Emphysema
#
#           info
# 0  PH951_v2129
# 1  PH951_v2129
# 2  PH951_v2129
# 3  PH951_v2129
# 4  PH951_v2129

# %%
df_sel_final['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    50
# Read3    24
# ICD10     5
# Name: count, dtype: int64

# %%
df_sel_final.to_csv(f'''{path}/copd_updated.csv''', index=False)

# %% [markdown]
# # Diabetes

# %%
df = pd.read_csv(f'''{P.codelist_path}/Diabetes_phenotype_PH152_ver_304_concepts_20231110T202045.csv''')
df.head()
# Out:
#       code                                        description  coding_system  \
# 0  C10F411               Type II diabetes mellitus with ulcer  Read codes v2
# 1  C108912            Type 1 diabetes mellitus maturity onset  Read codes v2
# 2  C10FQ00  Type 2 diabetes mellitus with exudative maculo...  Read codes v2
# 3  C108.12                           Type 1 diabetes mellitus  Read codes v2
# 4  C10F611         Type II diabetes mellitus with retinopathy  Read codes v2
#
#   concept_id  concept_version_id             concept_name phenotype_id  \
# 0      C1120                3379  Diabetes - Primary care        PH152
# 1      C1120                3379  Diabetes - Primary care        PH152
# 2      C1120                3379  Diabetes - Primary care        PH152
# 3      C1120                3379  Diabetes - Primary care        PH152
# 4      C1120                3379  Diabetes - Primary care        PH152
#
#    phenotype_version_id phenotype_name  \
# ...

# %%
df.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# ICD10 codes       15
# Med codes        135
# Read codes v2    135
# Name: code, dtype: int64

# %%
df["vocab"] = df["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes": "SNOMED", "Read codes v2": "Read2", "Med codes":"Med"})
df["code_clean"] = df["code"]
df.loc[df["vocab"] == "ICD10", "code_clean"] = df["code_clean"].str.replace(".", "")
df["pheno_name"] = "Diabetes"
df["info"] = "PH152_v304"
df['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    135
# Med      135
# ICD10     15
# Name: count, dtype: int64

# %%
df_sel =df[["pheno_name","code_clean", "vocab", "description","info"]]
df_sel.head()
# Out:
#   pheno_name code_clean  vocab  \
# 0   Diabetes    C10F411  Read2
# 1   Diabetes    C108912  Read2
# 2   Diabetes    C10FQ00  Read2
# 3   Diabetes    C108.12  Read2
# 4   Diabetes    C10F611  Read2
#
#                                          description        info
# 0               Type II diabetes mellitus with ulcer  PH152_v304
# 1            Type 1 diabetes mellitus maturity onset  PH152_v304
# 2  Type 2 diabetes mellitus with exudative maculo...  PH152_v304
# 3                           Type 1 diabetes mellitus  PH152_v304
# 4         Type II diabetes mellitus with retinopathy  PH152_v304

# %%
df_sel = df_sel[(df_sel["vocab"]=="Read2") | (df_sel["vocab"]=="ICD10")]
df_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    135
# ICD10     15
# Name: count, dtype: int64

# %%
# any CTV3?

df_read_new =  pd.merge(df_sel[(df_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
# Empty DataFrame
# Columns: [pheno_name, vocab, description, info, READV2_DESC, code_clean, TERMV3_DESC]
# Index: []

# %%
df_read_new = df_read_new[['pheno_name', 'code_clean', 'vocab', 'description', 'info']]

# %%
df_read_new.shape
# Out:
# (0, 5)

# %%
df_sel.to_csv(f'''{path}/diabetes.csv''', index=False)

# %% [markdown]
# # HF

# %%
df = pd.read_csv(f'''{P.codelist_path}/HF_phenotype_PH968_ver_2146_concepts_20231109T105756.csv''')
df.head()
# Out:
#         code                                        description  \
# 0   10335000       Chronic right-sided heart failure (disorder)
# 1  426263006  Congestive heart failure due to left ventricul...
# 2  420300004  New York Heart Association Classification - Cl...
# 3  134440006                   Referral to heart failure clinic
# 4   83105008  Malignant hypertensive heart disease with cong...
#
#       coding_system concept_id  concept_version_id  \
# 0  SNOMED  CT codes      C2792                7313
# 1  SNOMED  CT codes      C2792                7313
# 2  SNOMED  CT codes      C2792                7313
# 3  SNOMED  CT codes      C2792                7313
# 4  SNOMED  CT codes      C2792                7313
#
#                                         concept_name phenotype_id  \
# 0  CCU002_01 Heart failure - Phenotypes - England...        PH968
# 1  CCU002_01 Heart failure - Phenotypes - England...        PH968
# 2  CCU002_01 Heart failure - Phenotypes - England...        PH968
# ...

# %%
df.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# ICD10 codes          4
# Read codes v2       68
# SNOMED  CT codes    41
# Name: code, dtype: int64

# %%
df["vocab"] = df["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes": "SNOMED", "Read codes v2": "Read2"})
df["code_clean"] = df["code"]
df.loc[df["vocab"] == "ICD10", "code_clean"] = df["code_clean"].str.replace(".", "")
df["pheno_name"] = "HF"
df["info"] = "PH968_v2146"
df['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2     68
# SNOMED    41
# ICD10      4
# Name: count, dtype: int64

# %%
df_sel =df[["pheno_name","code_clean", "vocab", "description","info"]]
df_sel.head()
# Out:
#   pheno_name code_clean   vocab  \
# 0         HF   10335000  SNOMED
# 1         HF  426263006  SNOMED
# 2         HF  420300004  SNOMED
# 3         HF  134440006  SNOMED
# 4         HF   83105008  SNOMED
#
#                                          description         info
# 0       Chronic right-sided heart failure (disorder)  PH968_v2146
# 1  Congestive heart failure due to left ventricul...  PH968_v2146
# 2  New York Heart Association Classification - Cl...  PH968_v2146
# 3                   Referral to heart failure clinic  PH968_v2146
# 4  Malignant hypertensive heart disease with cong...  PH968_v2146

# %%
df_sel = df_sel[(df_sel["vocab"]=="Read2") | (df_sel["vocab"]=="ICD10")]
df_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    68
# ICD10     4
# Name: count, dtype: int64

# %%
# any CTV3?

df_read_new =  pd.merge(df_sel[(df_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
#   pheno_name  vocab                                        description  \
# 0         HF  Read3  Left ventricular dysfunction monitoring first ...
# 1         HF  Read3  Heart failure monitoring first letter         ...
# 2         HF  Read3  Referred by heart failure nurse specialist    ...
# 3         HF  Read3  New York Heart Association classification - cl...
# 4         HF  Read3  H/O: Heart failure in last year               ...
#
#           info                                        READV2_DESC code_clean  \
# 0  PH968_v2146  Left ventricular dysfunction monitoring first ...      XaK6Y
# 1  PH968_v2146              Heart failure monitoring first letter      XaMGs
# 2  PH968_v2146         Referred by heart failure nurse specialist      XaLCj
# 3  PH968_v2146  New York Heart Association classification - cl...      XaJ9H
# 4  PH968_v2146                    H/O: Heart failure in last year      XaBwi
#
#                                          TERMV3_DESC
# ...

# %%
df_read_new = df_read_new[['pheno_name', 'code_clean', 'vocab', 'description', 'info']]
df_read_new.shape
# Out:
# (66, 5)

# %%
df_sel_final = pd.concat([df_sel, df_read_new])
df_sel_final.head()
# Out:
#    pheno_name code_clean  vocab  \
# 41         HF        I50  ICD10
# 42         HF       I110  ICD10
# 43         HF       I130  ICD10
# 44         HF       I132  ICD10
# 45         HF      9On0.  Read2
#
#                                           description         info
# 41                                      Heart failure  PH968_v2146
# 42  Hypertensive heart disease with (congestive) h...  PH968_v2146
# 43  Hypertensive heart and renal disease with (con...  PH968_v2146
# 44  Hypertensive heart and renal disease with both...  PH968_v2146
# 45  Left ventricular dysfunction monitoring first ...  PH968_v2146

# %%
df_sel_final['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    68
# Read3    66
# ICD10     4
# Name: count, dtype: int64

# %%
df_sel_final.to_csv(f'''{path}/hf_updated.csv''', index=False)

# %% [markdown]
# # HT

# %%
df = pd.read_csv(f'''{P.codelist_path}/HT_phenotype_PH970_ver_2148_concepts_20231115T192946.csv''')
df.head()
# Out:
#   code                           description coding_system concept_id  \
# 0  I11            Hypertensive heart disease   ICD10 codes      C2796
# 1  I12            Hypertensive renal disease   ICD10 codes      C2796
# 2  I15                Secondary hypertension   ICD10 codes      C2796
# 3  I10      Essential (primary) hypertension   ICD10 codes      C2796
# 4  I13  Hypertensive heart and renal disease   ICD10 codes      C2796
#
#    concept_version_id                                       concept_name  \
# 0                7317  CCU002_01 Hypertension - Phenotypes - England ...
# 1                7317  CCU002_01 Hypertension - Phenotypes - England ...
# 2                7317  CCU002_01 Hypertension - Phenotypes - England ...
# 3                7317  CCU002_01 Hypertension - Phenotypes - England ...
# 4                7317  CCU002_01 Hypertension - Phenotypes - England ...
#
#   phenotype_id  phenotype_version_id          phenotype_name  \
# ...

# %%
df.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# BNF codes           849
# ICD10 codes           5
# Read codes v2        81
# SNOMED  CT codes     74
# Name: code, dtype: int64

# %%
df["vocab"] = df["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes": "SNOMED", "Read codes v2": "Read2","BFF code":"BNF"})
df["code_clean"] = df["code"]
df.loc[df["vocab"] == "ICD10", "code_clean"] = df["code_clean"].str.replace(".", "")
df["pheno_name"] = "HT"
df["info"] = "PH968_v2148"
df['vocab'].value_counts(dropna=False)
# Out:
# vocab
# NaN       849
# Read2      81
# SNOMED     74
# ICD10       5
# Name: count, dtype: int64

# %%
df_sel =df[["pheno_name","code_clean", "vocab", "description","info"]]
df_sel.head()
# Out:
#   pheno_name code_clean  vocab                           description  \
# 0         HT        I11  ICD10            Hypertensive heart disease
# 1         HT        I12  ICD10            Hypertensive renal disease
# 2         HT        I15  ICD10                Secondary hypertension
# 3         HT        I10  ICD10      Essential (primary) hypertension
# 4         HT        I13  ICD10  Hypertensive heart and renal disease
#
#           info
# 0  PH968_v2148
# 1  PH968_v2148
# 2  PH968_v2148
# 3  PH968_v2148
# 4  PH968_v2148

# %%
df_sel = df_sel[(df_sel["vocab"]=="Read2") | (df_sel["vocab"]=="ICD10")]
df_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    81
# ICD10     5
# Name: count, dtype: int64

# %%
# any CTV3?

df_read_new =  pd.merge(df_sel[(df_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
#   pheno_name  vocab                                        description  \
# 0         HT  Read3  Hypertensive retinopathy                      ...
# 1         HT  Read3  Secondary hypertension NOS                    ...
# 2         HT  Read3  Hypertension six month review                 ...
# 3         HT  Read3  Patient on maximal tolerated antihypertensive ...
# 4         HT  Read3  Hypertensive encephalopathy                   ...
#
#           info                                        READV2_DESC code_clean  \
# 0  PH968_v2148                           Hypertensive retinopathy      F4211
# 1  PH968_v2148                         Secondary hypertension NOS      G24z.
# 2  PH968_v2148                      Hypertension six month review      XaIyD
# 3  PH968_v2148  Patient on maximal tolerated antihypertensive ...      XaJ5h
# 4  PH968_v2148                        Hypertensive encephalopathy      XE0VM
#
#                                          TERMV3_DESC
# ...

# %%
df_read_new = df_read_new[['pheno_name', 'code_clean', 'vocab', 'description', 'info']]
df_read_new.shape
# Out:
# (39, 5)

# %%
df_sel_final = pd.concat([df_sel, df_read_new])
df_sel_final.head()
# Out:
#   pheno_name code_clean  vocab                           description  \
# 0         HT        I11  ICD10            Hypertensive heart disease
# 1         HT        I12  ICD10            Hypertensive renal disease
# 2         HT        I15  ICD10                Secondary hypertension
# 3         HT        I10  ICD10      Essential (primary) hypertension
# 4         HT        I13  ICD10  Hypertensive heart and renal disease
#
#           info
# 0  PH968_v2148
# 1  PH968_v2148
# 2  PH968_v2148
# 3  PH968_v2148
# 4  PH968_v2148

# %%
df_sel_final['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    81
# Read3    39
# ICD10     5
# Name: count, dtype: int64

# %%
df_sel_final.to_csv(f'''{path}/ht_updated.csv''', index=False)

# %% [markdown]
# # Stroke + NOS

# %%
df_stroke = pd.read_csv(f'''{P.codelist_path}/phenotype_PH983_ver_2161_concepts_20231109T105206.csv''')
df_stroke.head()
# Out:
#         code                                        description  \
# 0        I60               Nontraumatic subarachnoid hemorrhage
# 1        I61              Nontraumatic intracerebral hemorrhage
# 2  230709005  Massive supratentorial cerebral hemorrhage (di...
# 3  195165005                           Basal ganglia hemorrhage
# 4  276722003  Intracerebellar and posterior fossa hemorrhage...
#
#       coding_system concept_id  concept_version_id  \
# 0       ICD10 codes      C2822                7343
# 1       ICD10 codes      C2822                7343
# 2  SNOMED  CT codes      C2823                7344
# 3  SNOMED  CT codes      C2823                7344
# 4  SNOMED  CT codes      C2823                7344
#
#                                         concept_name phenotype_id  \
# 0  CCU002_01 Stroke - Phenotypes - England hospit...        PH983
# 1  CCU002_01 Stroke - Phenotypes - England hospit...        PH983
# 2  CCU002_01 Stroke - Phenotypes - England primar...        PH983
# ...

# %%
df_nos = pd.read_csv(f'''{P.codelist_path}/hdruk_pheno_library/phenotype_PH85_ver_170_concepts_20231109T105420.csv''')
df_nos.head()
# Out:
#       code                                        description  coding_system  \
# 0  14A7.11                                           H/O: CVA  Read codes v2
# 1  G66..00    Stroke and cerebrovascular accident unspecified  Read codes v2
# 2  9h21.00  Excepted from stroke quality indicators: Patie...  Read codes v2
# 3  14A7.12                                        H/O: stroke  Read codes v2
# 4  661M700                 Stroke self-management plan agreed  Read codes v2
#
#   concept_id  concept_version_id               concept_name phenotype_id  \
# 0       C918                2975  Stroke NOS - Primary care         PH85
# 1       C918                2975  Stroke NOS - Primary care         PH85
# 2       C918                2975  Stroke NOS - Primary care         PH85
# 3       C918                2975  Stroke NOS - Primary care         PH85
# 4       C918                2975  Stroke NOS - Primary care         PH85
#
#    phenotype_version_id phenotype_name  \
# ...

# %%
df_stroke.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# ICD10 codes         14
# Read codes v2       85
# SNOMED  CT codes    96
# Name: code, dtype: int64

# %%
df_nos.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# ICD10 codes       8
# Med codes        35
# Read codes v2    35
# Name: code, dtype: int64

# %%
df_stroke["vocab"] = df_stroke["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes": "SNOMED", "Read codes v2": "Read2","BFF code":"BNF", "Med codes":"Med"})
df_stroke["code_clean"] = df_stroke["code"]
df_stroke.loc[df_stroke["vocab"] == "ICD10", "code_clean"] = df_stroke["code_clean"].str.replace(".", "")
df_stroke.groupby(by="vocab").agg("count")["code"]
# Out:
# vocab
# ICD10     14
# Read2     85
# SNOMED    96
# Name: code, dtype: int64

# %%
df_nos["vocab"] = df_nos["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes": "SNOMED", "Read codes v2": "Read2","BFF code":"BNF", "Med codes":"Med"})
df_nos["code_clean"] = df_nos["code"]
df_nos.loc[df_nos["vocab"] == "ICD10", "code_clean"] = df_nos["code_clean"].str.replace(".", "")
df_nos.groupby(by="vocab").agg("count")["code"]
# Out:
# vocab
# ICD10     8
# Med      35
# Read2    35
# Name: code, dtype: int64

# %%
df_stroke_all = pd.concat([df_stroke, df_nos])

# %%
print(df_stroke.shape)
print(df_nos.shape)
print(df_stroke_all.shape)
# Out:
# (195, 12)
# (78, 12)
# (273, 12)

# %%
df_stroke_all["pheno_name"] = "Stroke"
df_stroke_all["info"] = "PH983_v2162_PH85_v170"
df_stroke_all['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2     120
# SNOMED     96
# Med        35
# ICD10      22
# Name: count, dtype: int64

# %%
df_stroke_sel = df_stroke_all[(df_stroke_all["vocab"]=="Read2") | (df_stroke_all["vocab"]=="ICD10")]
df_stroke_sel =df_stroke_sel[["pheno_name","code_clean", "vocab", "description", "info"]]

df_stroke_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    120
# ICD10     22
# Name: count, dtype: int64

# %%
df_stroke_sel.columns
# Out:
# Index(['pheno_name', 'code_clean', 'vocab', 'description', 'info'], dtype='object')

# %%
df_stroke_sel.head()
# Out:
#    pheno_name code_clean  vocab  \
# 0      Stroke        I60  ICD10
# 1      Stroke        I61  ICD10
# 25     Stroke        G45  ICD10
# 26     Stroke        H34  ICD10
# 27     Stroke       I630  ICD10
#
#                                           description                   info
# 0                Nontraumatic subarachnoid hemorrhage  PH983_v2162_PH85_v170
# 1               Nontraumatic intracerebral hemorrhage  PH983_v2162_PH85_v170
# 25  Transient cerebral ischaemic attacks and relat...  PH983_v2162_PH85_v170
# 26                        Retinal vascular occlusions  PH983_v2162_PH85_v170
# 27                                Cerebral infarction  PH983_v2162_PH85_v170

# %%
# any CTV3?

df_read_new =  pd.merge(df_stroke_sel[(df_stroke_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
#   pheno_name  vocab                                        description  \
# 0     Stroke  Read3  Cereb infarct due unsp occlus/stenos precerebr...
# 1     Stroke  Read3  Central post-stroke pain                      ...
# 2     Stroke  Read3  CVA - cerebrovascular accident in the puerperi...
# 3     Stroke  Read3  CVA - cerebrovascular accident in the puerperi...
# 4     Stroke  Read3  CVA - cerebrovascular accident in the puerperi...
#
#                     info                                        READV2_DESC  \
# 0  PH983_v2162_PH85_v170  Cerebral infarction due to unspecified occlusi...
# 1  PH983_v2162_PH85_v170                           Central post-stroke pain
# 2  PH983_v2162_PH85_v170        Cerebrovascular disorders in the puerperium
# 3  PH983_v2162_PH85_v170        Cerebrovascular disorders in the puerperium
# 4  PH983_v2162_PH85_v170        Cerebrovascular disorders in the puerperium
#
#   code_clean                                        TERMV3_DESC
# ...

# %%
df_read_new = df_read_new[['pheno_name', 'code_clean', 'vocab', 'description', 'info']]
df_read_new.shape
# Out:
# (72, 5)

# %%
df_sel_final = pd.concat([df_stroke_sel, df_read_new])
df_sel_final.head()
# Out:
#    pheno_name code_clean  vocab  \
# 0      Stroke        I60  ICD10
# 1      Stroke        I61  ICD10
# 25     Stroke        G45  ICD10
# 26     Stroke        H34  ICD10
# 27     Stroke       I630  ICD10
#
#                                           description                   info
# 0                Nontraumatic subarachnoid hemorrhage  PH983_v2162_PH85_v170
# 1               Nontraumatic intracerebral hemorrhage  PH983_v2162_PH85_v170
# 25  Transient cerebral ischaemic attacks and relat...  PH983_v2162_PH85_v170
# 26                        Retinal vascular occlusions  PH983_v2162_PH85_v170
# 27                                Cerebral infarction  PH983_v2162_PH85_v170

# %%
df_sel_final['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    120
# Read3     72
# ICD10     22
# Name: count, dtype: int64

# %%
df_sel_final.to_csv(f'''{path}/stroke_updated.csv''', index=False)

# %% [markdown]
# # PE

# %%
df = pd.read_csv(f'''{P.codelist_path}/PE_phenotype_PH978_ver_2156_concepts_20231115T192721.csv''')
df.head()
# Out:
#               code                                        description  \
# 0            I26.9                                 Pulmonary embolism
# 1            I26.0                                 Pulmonary embolism
# 2        438773007  Pulmonary embolism with mention of acute cor p...
# 3  133971000119108  Pulmonary embolism with mention of acute cor p...
# 4            7A0A1  Percutaneous transluminal embolectomy of pulmo...
#
#       coding_system concept_id  concept_version_id  \
# 0       ICD10 codes      C2813                7334
# 1       ICD10 codes      C2813                7334
# 2  SNOMED  CT codes      C2814                7335
# 3  SNOMED  CT codes      C2814                7335
# 4     Read codes v2      C2815                7336
#
#                                         concept_name phenotype_id  \
# 0  CCU002_01 Pulmonary embolismm (PE) - Phenotype...        PH978
# 1  CCU002_01 Pulmonary embolismm (PE) - Phenotype...        PH978
# ...

# %%
df.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# ICD10 codes         2
# Read codes v2       8
# SNOMED  CT codes    2
# Name: code, dtype: int64

# %%
df["vocab"] = df["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes": "SNOMED", "Read codes v2": "Read2","BFF code":"BNF"})
df["code_clean"] = df["code"]
df.loc[df["vocab"] == "ICD10", "code_clean"] = df["code_clean"].str.replace(".", "")
df["pheno_name"] = "PE"
df["info"] = "PH978_v2156"
df['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2     8
# ICD10     2
# SNOMED    2
# Name: count, dtype: int64

# %%
df_sel =df[["pheno_name","code_clean", "vocab", "description", "info"]]
df_sel.head()
# Out:
#   pheno_name       code_clean   vocab  \
# 0         PE             I269   ICD10
# 1         PE             I260   ICD10
# 2         PE        438773007  SNOMED
# 3         PE  133971000119108  SNOMED
# 4         PE            7A0A1   Read2
#
#                                          description         info
# 0                                 Pulmonary embolism  PH978_v2156
# 1                                 Pulmonary embolism  PH978_v2156
# 2  Pulmonary embolism with mention of acute cor p...  PH978_v2156
# 3  Pulmonary embolism with mention of acute cor p...  PH978_v2156
# 4  Percutaneous transluminal embolectomy of pulmo...  PH978_v2156

# %%
df_sel = df_sel[(df_sel["vocab"]=="Read2") | (df_sel["vocab"]=="ICD10")]
df_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    8
# ICD10    2
# Name: count, dtype: int64

# %%
# any CTV3?

df_read_new =  pd.merge(df_sel[(df_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
#   pheno_name  vocab                                        description  \
# 0         PE  Read3  Pulmonary thromboendarterectomy               ...
# 1         PE  Read3  Pulmonary embolism                            ...
# 2         PE  Read3  Pulmonary embolism                            ...
# 3         PE  Read3  Pulmonary embolism                            ...
# 4         PE  Read3  Recurrent pulmonary embolism                  ...
#
#           info                      READV2_DESC code_clean  \
# 0  PH978_v2156  Pulmonary thromboendarterectomy      XaLgy
# 1  PH978_v2156               Pulmonary embolism      XE0Um
# 2  PH978_v2156               Pulmonary embolism      G402.
# 3  PH978_v2156               Pulmonary embolism      XE0Um
# 4  PH978_v2156     Recurrent pulmonary embolism      XaOYV
#
#                        TERMV3_DESC
# 0  Pulmonary thromboendarterectomy
# 1               Pulmonary embolism
# 2             Pulmonary infarction
# 3                Pulmonary embolus
# ...

# %%
df_read_new = df_read_new[['pheno_name', 'code_clean', 'vocab', 'description', 'info']]
df_read_new.shape
# Out:
# (6, 5)

# %%
df_sel_final = pd.concat([df_sel, df_read_new])
df_sel_final.head()
# Out:
#   pheno_name code_clean  vocab  \
# 0         PE       I269  ICD10
# 1         PE       I260  ICD10
# 4         PE      7A0A1  Read2
# 5         PE      7A093  Read2
# 6         PE      7A0B0  Read2
#
#                                          description         info
# 0                                 Pulmonary embolism  PH978_v2156
# 1                                 Pulmonary embolism  PH978_v2156
# 4  Percutaneous transluminal embolectomy of pulmo...  PH978_v2156
# 5  Open embolectomy of pulmonary artery          ...  PH978_v2156
# 6  Pulmonary thromboendarterectomy               ...  PH978_v2156

# %%
df_sel_final['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    8
# Read3    6
# ICD10    2
# Name: count, dtype: int64

# %%
df_sel_final.to_csv(f'''{path}/pe_updated.csv''', index=False)

# %% [markdown]
# # CKD

# %%
df_ckd_3_5 = pd.read_csv(f'''{P.codelist_path}/ckd/CKD_AD_Satges3_5_Dec2023.csv''')
df_ckd_3_5.head()
# Out:
#   Concept ID Coding System CKD Stage  \
# 0      T82.4        ICD-10         5
# 1      T86.1        ICD-10         5
# 2      Y60.2        ICD-10         5
# 3      Y61.2        ICD-10         5
# 4      Y62.2        ICD-10         5
#
#                                        Clinical Term
# 0  mechanical complication of vascular dialysis c...
# 1            kidney transplant failure and rejection
# 2          during kidney dialysis or other perfusion
# 3          during kidney dialysis or other perfusion
# 4          during kidney dialysis or other perfusion

# %%
df_ckd_3_5.groupby(by="Coding System").agg("count")["Concept ID"]
# Out:
# Coding System
# ICD-10        17
# Read-Code    131
# SNOMED       103
# Name: Concept ID, dtype: int64

# %%
df_ckd_3_5["vocab"] = df_ckd_3_5["Coding System"].map({"ICD-10": "ICD10", "Read-Code": "Read2"})
df_ckd_3_5["code"] = df_ckd_3_5["Concept ID"]
df_ckd_3_5["description"] = df_ckd_3_5["Clinical Term"]

# %%
df_ckd_3_5.groupby(by="vocab").agg("count")["code"]
# Out:
# vocab
# ICD10     17
# Read2    131
# Name: code, dtype: int64

# %%
df_ckd_3_5.groupby(by="Coding System").agg("count")["Concept ID"]
# Out:
# Coding System
# ICD-10        17
# Read-Code    131
# SNOMED       103
# Name: Concept ID, dtype: int64

# %%
df_ckd_3_5.head()
# Out:
#   Concept ID Coding System CKD Stage  \
# 0      T82.4        ICD-10         5
# 1      T86.1        ICD-10         5
# 2      Y60.2        ICD-10         5
# 3      Y61.2        ICD-10         5
# 4      Y62.2        ICD-10         5
#
#                                        Clinical Term  vocab   code  \
# 0  mechanical complication of vascular dialysis c...  ICD10  T82.4
# 1            kidney transplant failure and rejection  ICD10  T86.1
# 2          during kidney dialysis or other perfusion  ICD10  Y60.2
# 3          during kidney dialysis or other perfusion  ICD10  Y61.2
# 4          during kidney dialysis or other perfusion  ICD10  Y62.2
#
#                                          description
# 0  mechanical complication of vascular dialysis c...
# 1            kidney transplant failure and rejection
# 2          during kidney dialysis or other perfusion
# 3          during kidney dialysis or other perfusion
# 4          during kidney dialysis or other perfusion

# %%
df_ckd_3_5["code_clean"] = df_ckd_3_5["code"]
df_ckd_3_5.loc[df_ckd_3_5["vocab"] == "ICD10", "code_clean"] = df_ckd_3_5["code_clean"].str.replace(".", "")
df_ckd_3_5["pheno_name"] = "CKD345"
df_ckd_3_5["info"] = "CCU003_01"
df_ckd_3_5['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    131
# NaN      103
# ICD10     17
# Name: count, dtype: int64

# %%
df_ckd_3_5_sel = df_ckd_3_5[["pheno_name","code_clean", "vocab", "description", "info"]]
df_ckd_3_5_sel.head()
# Out:
#   pheno_name code_clean  vocab  \
# 0     CKD345       T824  ICD10
# 1     CKD345       T861  ICD10
# 2     CKD345       Y602  ICD10
# 3     CKD345       Y612  ICD10
# 4     CKD345       Y622  ICD10
#
#                                          description       info
# 0  mechanical complication of vascular dialysis c...  CCU003_01
# 1            kidney transplant failure and rejection  CCU003_01
# 2          during kidney dialysis or other perfusion  CCU003_01
# 3          during kidney dialysis or other perfusion  CCU003_01
# 4          during kidney dialysis or other perfusion  CCU003_01

# %%
df_ckd_3_5_sel = df_ckd_3_5_sel[(df_ckd_3_5_sel["vocab"]=="Read2") | (df_ckd_3_5_sel["vocab"]=="ICD10")]
df_ckd_3_5_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    131
# ICD10     17
# Name: count, dtype: int64

# %%
# any CTV3?

df_read_new =  pd.merge(df_ckd_3_5_sel[(df_ckd_3_5_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
# Empty DataFrame
# Columns: [pheno_name, vocab, description, info, READV2_DESC, code_clean, TERMV3_DESC]
# Index: []

# %%
df_ckd_3_5_sel.to_csv(f'''{path}/ckd345_updated.csv''', index=False)

# %% [markdown]
# # Atrial fibrilation

# %%
df = pd.read_csv(f'''{P.codelist_path}/AF_phenotype_PH36_ver_72_concepts_20231204T185155.csv''')
df.head()
# Out:
#       code                                   description  coding_system  \
# 0  9Os3.00  Atrial fibrillation monitoring verbal invite  Read codes v2
# 1  G573000                           Atrial fibrillation  Read codes v2
# 2  14AR.00                     History of atrial flutter  Read codes v2
# 3  212R.00                  Atrial fibrillation resolved  Read codes v2
# 4  9Os0.00   Atrial fibrillation monitoring first letter  Read codes v2
#
#   concept_id  concept_version_id                        concept_name  \
# 0       C789                2717  Atrial fibrillation - Primary care
# 1       C789                2717  Atrial fibrillation - Primary care
# 2       C789                2717  Atrial fibrillation - Primary care
# 3       C789                2717  Atrial fibrillation - Primary care
# 4       C789                2717  Atrial fibrillation - Primary care
#
#   phenotype_id  phenotype_version_id       phenotype_name  \
# ...

# %%
df.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# ICD10 codes       1
# Med codes        23
# Read codes v2    23
# Name: code, dtype: int64

# %%
df["vocab"] = df["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes": "SNOMED", "Read codes v2": "Read2","BFF code":"BNF", "Med codes":"Med"})
df["code_clean"] = df["code"]
df.loc[df["vocab"] == "ICD10", "code_clean"] = df["code_clean"].str.replace(".", "")
df["pheno_name"] = "AF"
df["info"] = "PH36_v72"
df['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    23
# Med      23
# ICD10     1
# Name: count, dtype: int64

# %%
df_sel =df[["pheno_name","code_clean", "vocab", "description","info"]]
df_sel.head()
# Out:
#   pheno_name code_clean  vocab                                   description  \
# 0         AF    9Os3.00  Read2  Atrial fibrillation monitoring verbal invite
# 1         AF    G573000  Read2                           Atrial fibrillation
# 2         AF    14AR.00  Read2                     History of atrial flutter
# 3         AF    212R.00  Read2                  Atrial fibrillation resolved
# 4         AF    9Os0.00  Read2   Atrial fibrillation monitoring first letter
#
#        info
# 0  PH36_v72
# 1  PH36_v72
# 2  PH36_v72
# 3  PH36_v72
# 4  PH36_v72

# %%
df_sel = df_sel[(df_sel["vocab"]=="Read2") | (df_sel["vocab"]=="ICD10")]
df_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    23
# ICD10     1
# Name: count, dtype: int64

# %%
# any CTV3?

df_read_new =  pd.merge(df_sel[(df_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
# Empty DataFrame
# Columns: [pheno_name, vocab, description, info, READV2_DESC, code_clean, TERMV3_DESC]
# Index: []

# %%
df_sel.to_csv(f'''{path}/af.csv''', index=False)

# %% [markdown]
# # DVT

# %%
df = pd.read_csv(f'''{P.codelist_path}/dvt_phenotype_PH966_ver_2144_concepts_20231204T190037.csv''')
df.head()
# Out:
#         code                                        description  \
# 0        I80                     Phlebitis and thrombophlebitis
# 1      I67.6                     Intracranial venous thrombosis
# 2        G08                     Intracranial venous thrombosis
# 3      I63.6                     Intracranial venous thrombosis
# 4  195230003  Cerebral infarction due to cerebral venous thr...
#
#       coding_system concept_id  concept_version_id  \
# 0       ICD10 codes      C2783                7304
# 1       ICD10 codes      C2784                7305
# 2       ICD10 codes      C2784                7305
# 3       ICD10 codes      C2784                7305
# 4  SNOMED  CT codes      C2785                7306
#
#                                         concept_name phenotype_id  \
# 0  CCU002_01 Deep vein thrombosis, intracranial v...        PH966
# 1  CCU002_01 Deep vein thrombosis, intracranial v...        PH966
# 2  CCU002_01 Deep vein thrombosis, intracranial v...        PH966
# ...

# %%
df.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# ICD10 codes         16
# Read codes v2        1
# SNOMED  CT codes     1
# Name: code, dtype: int64

# %%
df["vocab"] = df["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes": "SNOMED", "Read codes v2": "Read2","BFF code":"BNF", "Med codes":"Med"})
df["code_clean"] = df["code"]
df.loc[df["vocab"] == "ICD10", "code_clean"] = df["code_clean"].str.replace(".", "")
df["pheno_name"] = "DVT"
df["info"] = "PH966_v2144"
df['vocab'].value_counts(dropna=False)
# Out:
# vocab
# ICD10     16
# SNOMED     1
# Read2      1
# Name: count, dtype: int64

# %%
df_sel =df[["pheno_name","code_clean", "vocab", "description", "info"]]
df_sel = df_sel[(df_sel["vocab"]=="Read2") | (df_sel["vocab"]=="ICD10")]

df_sel.head()
# Out:
#   pheno_name code_clean  vocab                                 description  \
# 0        DVT        I80  ICD10              Phlebitis and thrombophlebitis
# 1        DVT       I676  ICD10              Intracranial venous thrombosis
# 2        DVT        G08  ICD10              Intracranial venous thrombosis
# 3        DVT       I636  ICD10              Intracranial venous thrombosis
# 5        DVT       O879  ICD10  Thrombosis during pregnancy and puerperium
#
#           info
# 0  PH966_v2144
# 1  PH966_v2144
# 2  PH966_v2144
# 3  PH966_v2144
# 5  PH966_v2144

# %%
df_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# ICD10    16
# Read2     1
# Name: count, dtype: int64

# %%
# any CTV3?

df_read_new =  pd.merge(df_sel[(df_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
# Empty DataFrame
# Columns: [pheno_name, vocab, description, info, READV2_DESC, code_clean, TERMV3_DESC]
# Index: []

# %%
df_sel.to_csv(f'''{path}/dvt.csv''', index=False)

# %% [markdown]
# # PAD

# %%
df = pd.read_csv(f'''{P.codelist_path}/pad_phenotype_PH236_ver_472_concepts_20231204T190615.csv''')
df.head()
# Out:
#       code                                        description  coding_system  \
# 0  7A12312                          Dacron aortoiliac Y graft  Read codes v2
# 1  7A49.11            Reconstruction of common femoral artery  Read codes v2
# 2  7A48200  Bypass femoral artery by fem/pop art anast c v...  Read codes v2
# 3  G73yz00    Other specified peripheral vascular disease NOS  Read codes v2
# 4  7A48800  Bypass femoral artery by fem/peron a anast c p...  Read codes v2
#
#   concept_id  concept_version_id                                concept_name  \
# 0      C1349                3837  Peripheral arterial disease - Primary care
# 1      C1349                3837  Peripheral arterial disease - Primary care
# 2      C1349                3837  Peripheral arterial disease - Primary care
# 3      C1349                3837  Peripheral arterial disease - Primary care
# 4      C1349                3837  Peripheral arterial disease - Primary care
#
# ...

# %%
df.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# ICD10 codes        6
# Med codes        201
# OPCS4 codes       71
# Read codes v2    201
# Name: code, dtype: int64

# %%
df["vocab"] = df["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes": "SNOMED", "Read codes v2": "Read2","BFF code":"BNF", "Med codes":"Med"})
df["code_clean"] = df["code"]
df.loc[df["vocab"] == "ICD10", "code_clean"] = df["code_clean"].str.replace(".", "")
df["pheno_name"] = "PAD"
df["info"] = "PH236_v472"
df['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    201
# Med      201
# NaN       71
# ICD10      6
# Name: count, dtype: int64

# %%
df_sel =df[["pheno_name","code_clean", "vocab", "description","info"]]
df_sel = df_sel[(df_sel["vocab"]=="Read2") | (df_sel["vocab"]=="ICD10")]

df_sel.head()
# Out:
#   pheno_name code_clean  vocab  \
# 0        PAD    7A12312  Read2
# 1        PAD    7A49.11  Read2
# 2        PAD    7A48200  Read2
# 3        PAD    G73yz00  Read2
# 4        PAD    7A48800  Read2
#
#                                          description        info
# 0                          Dacron aortoiliac Y graft  PH236_v472
# 1            Reconstruction of common femoral artery  PH236_v472
# 2  Bypass femoral artery by fem/pop art anast c v...  PH236_v472
# 3    Other specified peripheral vascular disease NOS  PH236_v472
# 4  Bypass femoral artery by fem/peron a anast c p...  PH236_v472

# %%
df_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    201
# ICD10      6
# Name: count, dtype: int64

# %%
# any CTV3?

df_read_new =  pd.merge(df_sel[(df_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
# Empty DataFrame
# Columns: [pheno_name, vocab, description, info, READV2_DESC, code_clean, TERMV3_DESC]
# Index: []

# %%
df_sel.to_csv(f'''{path}/pad.csv''', index=False)

# %% [markdown]
# # Depression

# %%
df = pd.read_csv(f'''{P.codelist_path}/depression_phenotype_PH964_ver_2142_concepts_20231204T190936.csv''')
df.head()
# Out:
#               code                                        description  \
# 0              F32                                 Depressive episode
# 1              F33                      Recurrent depressive disorder
# 2        231499006     Endogenous depression first episode (disorder)
# 3        370143000               Major depressive disorder (disorder)
# 4  755321000000106  Single major depressive episode, severe, with ...
#
#       coding_system concept_id  concept_version_id  \
# 0       ICD10 codes      C2778                7299
# 1       ICD10 codes      C2778                7299
# 2  SNOMED  CT codes      C2779                7300
# 3  SNOMED  CT codes      C2779                7300
# 4  SNOMED  CT codes      C2779                7300
#
#                                         concept_name phenotype_id  \
# 0  CCU002_01 Depression - Phenotypes - England ho...        PH964
# 1  CCU002_01 Depression - Phenotypes - England ho...        PH964
# ...

# %%
df.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# ICD10 codes          2
# Read codes v2       75
# SNOMED  CT codes    67
# Name: code, dtype: int64

# %%
df["vocab"] = df["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes": "SNOMED", "Read codes v2": "Read2","BFF code":"BNF", "Med codes":"Med"})
df["code_clean"] = df["code"]
df.loc[df["vocab"] == "ICD10", "code_clean"] = df["code_clean"].str.replace(".", "")
df["pheno_name"] = "Depression"
df["info"] = "PH964_2142"
df['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2     75
# SNOMED    67
# ICD10      2
# Name: count, dtype: int64

# %%
df_sel =df[["pheno_name","code_clean", "vocab","description", "info"]]
df_sel = df_sel[(df_sel["vocab"]=="Read2") | (df_sel["vocab"]=="ICD10")]

df_sel.head()
# Out:
#     pheno_name code_clean  vocab  \
# 0   Depression        F32  ICD10
# 1   Depression        F33  ICD10
# 69  Depression      Eu33y  Read2
# 70  Depression      9H91.  Read2
# 71  Depression      Eu251  Read2
#
#                                           description        info
# 0                                  Depressive episode  PH964_2142
# 1                       Recurrent depressive disorder  PH964_2142
# 69  [X]Other recurrent depressive disorders       ...  PH964_2142
# 70  Depression medication review                  ...  PH964_2142
# 71  [X]Schizoaffective disorder, depressive type  ...  PH964_2142

# %%
df_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    75
# ICD10     2
# Name: count, dtype: int64

# %%
# any CTV3?

df_read_new =  pd.merge(df_sel[(df_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
#    pheno_name  vocab                                        description  \
# 0  Depression  Read3  Depression medication review                  ...
# 1  Depression  Read3  [X]Schizoaffective disorder, depressive type  ...
# 2  Depression  Read3  [X]Schizoaffective disorder, depressive type  ...
# 3  Depression  Read3  [X]Schizoaffective disorder, depressive type  ...
# 4  Depression  Read3  [X]Schizoaffective disorder, depressive type  ...
#
#          info                                   READV2_DESC code_clean  \
# 0  PH964_2142                  Depression medication review      XaK6e
# 1  PH964_2142  [X]Schizoaffective disorder, depressive type      XE2un
# 2  PH964_2142  [X]Schizoaffective disorder, depressive type      XE2un
# 3  PH964_2142  [X]Schizoaffective disorder, depressive type      XE2un
# 4  PH964_2142  [X]Schizoaffective disorder, depressive type      XE2un
#
#                                    TERMV3_DESC
# 0                 Depression medication review
# ...

# %%
df_read_new = df_read_new[['pheno_name', 'code_clean', 'vocab', 'description', 'info']]
df_read_new.shape
# Out:
# (106, 5)

# %%
df_sel_final = pd.concat([df_sel, df_read_new])
df_sel_final.head()
# Out:
#     pheno_name code_clean  vocab  \
# 0   Depression        F32  ICD10
# 1   Depression        F33  ICD10
# 69  Depression      Eu33y  Read2
# 70  Depression      9H91.  Read2
# 71  Depression      Eu251  Read2
#
#                                           description        info
# 0                                  Depressive episode  PH964_2142
# 1                       Recurrent depressive disorder  PH964_2142
# 69  [X]Other recurrent depressive disorders       ...  PH964_2142
# 70  Depression medication review                  ...  PH964_2142
# 71  [X]Schizoaffective disorder, depressive type  ...  PH964_2142

# %%
df_sel_final['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read3    106
# Read2     75
# ICD10      2
# Name: count, dtype: int64

# %%
df_sel_final.to_csv(f'''{path}/depression_updated.csv''', index=False)

# %% [markdown]
# # Obesity

# %%
df = pd.read_csv(f'''{P.codelist_path}/obesity_phenotype_PH221_ver_442_concepts_20231205T120131.csv''')
df.head()
# Out:
#         code                     description  coding_system concept_id  \
# 0    C38z000              Simple obesity NOS  Read codes v2      C1314
# 1    66C..00              Obesity monitoring  Read codes v2      C1314
# 2    C380000  Obesity due to excess calories  Read codes v2      C1314
# 3    C380400                 Central obesity  Read codes v2      C1314
# 4  7613600.0     Maintenance of gastric band  Read codes v2      C1314
#
#    concept_version_id            concept_name phenotype_id  \
# 0                3767  Obesity - Primary care        PH221
# 1                3767  Obesity - Primary care        PH221
# 2                3767  Obesity - Primary care        PH221
# 3                3767  Obesity - Primary care        PH221
# 4                3767  Obesity - Primary care        PH221
#
#    phenotype_version_id phenotype_name  \
# 0                   442        Obesity
# 1                   442        Obesity
# 2                   442        Obesity
# ...

# %%
df.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# ICD10 codes       1
# Med codes        70
# Read codes v2    70
# Name: code, dtype: int64

# %%
df["vocab"] = df["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes": "SNOMED", "Read codes v2": "Read2","BFF code":"BNF", "Med codes":"Med"})
df["code_clean"] = df["code"]
df.loc[df["vocab"] == "ICD10", "code_clean"] = df["code_clean"].str.replace(".", "")
df["pheno_name"] = "Obesity"
df["info"] = "PH221_442"
df['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    70
# Med      70
# ICD10     1
# Name: count, dtype: int64

# %%
df_sel =df[["pheno_name","code_clean", "vocab", "description","info"]]
df_sel = df_sel[(df_sel["vocab"]=="Read2") | (df_sel["vocab"]=="ICD10")]

df_sel.head()
# Out:
#   pheno_name code_clean  vocab                     description       info
# 0    Obesity    C38z000  Read2              Simple obesity NOS  PH221_442
# 1    Obesity    66C..00  Read2              Obesity monitoring  PH221_442
# 2    Obesity    C380000  Read2  Obesity due to excess calories  PH221_442
# 3    Obesity    C380400  Read2                 Central obesity  PH221_442
# 4    Obesity  7613600.0  Read2     Maintenance of gastric band  PH221_442

# %%
df_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    70
# ICD10     1
# Name: count, dtype: int64

# %%
# any CTV3?

df_read_new =  pd.merge(df_sel[(df_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
# Empty DataFrame
# Columns: [pheno_name, vocab, description, info, READV2_DESC, code_clean, TERMV3_DESC]
# Index: []

# %%
df_sel.to_csv(f'''{path}/obesity.csv''', index=False)

# %% [markdown]
# # Dementia

# %%
df = pd.read_csv(f'''{P.codelist_path}/dementia_phenotype_PH963_ver_2141_concepts_20231205T122311.csv''')
df.head()
# Out:
#               code                                        description  \
# 0              F00                    Dementia in Alzheimer's disease
# 1              F03                               Unspecified dementia
# 2              G30                                Alzheimer's disease
# 3            F05.1                  Delirium superimposed on dementia
# 4  419261000000107  [X]Dementia in Alzheimer's dis, atypical or mi...
#
#       coding_system concept_id  concept_version_id  \
# 0       ICD10 codes      C2773                7294
# 1       ICD10 codes      C2773                7294
# 2       ICD10 codes      C2773                7294
# 3       ICD10 codes      C2773                7294
# 4  SNOMED  CT codes      C2774                7295
#
#                                         concept_name phenotype_id  \
# 0  CCU002_01 Dementia - Phenotypes - England hosp...        PH963
# 1  CCU002_01 Dementia - Phenotypes - England hosp...        PH963
# ...

# %%
df.groupby(by="coding_system").agg("count")["code"]
# Out:
# coding_system
# ICD10 codes          5
# Read codes v2       54
# SNOMED  CT codes    91
# Name: code, dtype: int64

# %%
df["vocab"] = df["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes": "SNOMED", "Read codes v2": "Read2","BFF code":"BNF", "Med codes":"Med"})
df["code_clean"] = df["code"]
df.loc[df["vocab"] == "ICD10", "code_clean"] = df["code_clean"].str.replace(".", "")
df["pheno_name"] = "Dementia"
df["info"] = "PH963_2141"
df['vocab'].value_counts(dropna=False)
# Out:
# vocab
# SNOMED    91
# Read2     54
# ICD10      5
# Name: count, dtype: int64

# %%
df_sel =df[["pheno_name","code_clean", "vocab", "description","info"]]
df_sel = df_sel[(df_sel["vocab"]=="Read2") | (df_sel["vocab"]=="ICD10")]

df_sel.head()
# Out:
#    pheno_name code_clean  vocab                        description        info
# 0    Dementia        F00  ICD10    Dementia in Alzheimer's disease  PH963_2141
# 1    Dementia        F03  ICD10               Unspecified dementia  PH963_2141
# 2    Dementia        G30  ICD10                Alzheimer's disease  PH963_2141
# 3    Dementia       F051  ICD10  Delirium superimposed on dementia  PH963_2141
# 83   Dementia        F01  ICD10                  Vascular dementia  PH963_2141

# %%
df_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    54
# ICD10     5
# Name: count, dtype: int64

# %%
df_sel.to_csv(f'''{path}/dementia.csv''', index=False)

# %%
# any CTV3?

df_read_new =  pd.merge(df_sel[(df_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
#   pheno_name  vocab                                        description  \
# 0   Dementia  Read3  [X]Mixed cortical and subcortical vascular dem...
# 1   Dementia  Read3  Dementia monitoring telephone invite          ...
# 2   Dementia  Read3  [X]Dementia in Alzheimer's disease with late o...
# 3   Dementia  Read3  [X]Dementia in Alzheimer's disease with late o...
# 4   Dementia  Read3  [X]Dementia in Alzheimer's disease with late o...
#
#          info                                        READV2_DESC code_clean  \
# 0  PH963_2141  [X]Mixed cortical and subcortical vascular dem...      X003V
# 1  PH963_2141               Dementia monitoring telephone invite      XaMGK
# 2  PH963_2141  [X]Dementia in Alzheimer's disease with late o...      X0030
# 3  PH963_2141  [X]Dementia in Alzheimer's disease with late o...      X0030
# 4  PH963_2141  [X]Dementia in Alzheimer's disease with late o...      X0030
#
#                                         TERMV3_DESC
# ...

# %%
df_read_new = df_read_new[['pheno_name', 'code_clean', 'vocab', 'description', 'info']]
df_read_new.shape
# Out:
# (54, 5)

# %%
df_sel_final = pd.concat([df_sel, df_read_new])
df_sel_final.head()
# Out:
#    pheno_name code_clean  vocab                        description        info
# 0    Dementia        F00  ICD10    Dementia in Alzheimer's disease  PH963_2141
# 1    Dementia        F03  ICD10               Unspecified dementia  PH963_2141
# 2    Dementia        G30  ICD10                Alzheimer's disease  PH963_2141
# 3    Dementia       F051  ICD10  Delirium superimposed on dementia  PH963_2141
# 83   Dementia        F01  ICD10                  Vascular dementia  PH963_2141

# %%
df_sel_final['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    54
# Read3    54
# ICD10     5
# Name: count, dtype: int64

# %%
df_sel_final.to_csv(f'''{path}/dementia_updated.csv''', index=False)

# %%
df_sel.head()
# Out:
#    pheno_name code_clean  vocab                        description        info
# 0    Dementia        F00  ICD10    Dementia in Alzheimer's disease  PH963_2141
# 1    Dementia        F03  ICD10               Unspecified dementia  PH963_2141
# 2    Dementia        G30  ICD10                Alzheimer's disease  PH963_2141
# 3    Dementia       F051  ICD10  Delirium superimposed on dementia  PH963_2141
# 83   Dementia        F01  ICD10                  Vascular dementia  PH963_2141

# %% [markdown]
# # Smoking

# %%
df = pd.read_csv(f'''{P.codelist_path}/smoking/phenotype_PH350_ver_1513_concepts_20231224T173857.csv''')
df.head(100)
# Out:
#        code                                        description  coding_system  \
# 0   137K.00                                    Stopped smoking  Read codes v2
# 1   137O.00                                    Ex cigar smoker  Read codes v2
# 2      1379                     Ex-moderate smoker (10-19/day)  Read codes v2
# 3   137S.00                                          Ex smoker  Read codes v2
# 4   137N.00                                     Ex pipe smoker  Read codes v2
# 5      1377                         Ex-trivial smoker (<1/day)  Read codes v2
# 6   137T.00                                Date ceased smoking  Read codes v2
# 7   ZV11600               [V]Personal history of tobacco abuse  Read codes v2
# 8   H310100                                     Smokers' cough  Read codes v2
# 9   137L.00                                 Current non-smoker  Read codes v2
# 10  137j.00                                Ex-cigarette smoker  Read codes v2
# ...

# %%
import json
df['status'] = df['code_attributes'].apply(lambda x: json.loads(x)[0].get("CALIBER category"))

# %%
df.groupby("status").size().reset_index(name="Counts")
# Out:
#                  status  Counts
# 0        Current smoker       3
# 1  Ex or current smoker       2
# 2             Ex smoker      14
# 3            Non smoker       5

# %%
df["vocab"] = df["coding_system"].map({"ICD10 codes": "ICD10", "SNOMED  CT codes": "SNOMED", "Read codes v2": "Read2","BFF code":"BNF", "Med codes":"Med"})
df["code_clean"] = df["code"]
df.loc[df["vocab"] == "ICD10", "code_clean"] = df["code_clean"].str.replace(".", "")
df["pheno_name"] = "smoking"
df["info"] = "PH350_1513"
df['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    21
# ICD10     3
# Name: count, dtype: int64

# %%
df_sel = df[["pheno_name", "code_clean", "vocab", "description", "status", "info"]]
df_sel
# Out:
#    pheno_name code_clean  vocab  \
# 0     smoking    137K.00  Read2
# 1     smoking    137O.00  Read2
# 2     smoking       1379  Read2
# 3     smoking    137S.00  Read2
# 4     smoking    137N.00  Read2
# 5     smoking       1377  Read2
# 6     smoking    137T.00  Read2
# 7     smoking    ZV11600  Read2
# 8     smoking    H310100  Read2
# 9     smoking    137L.00  Read2
# 10    smoking    137j.00  Read2
# 11    smoking    137A.00  Read2
# 12    smoking    9km..00  Read2
# 13    smoking    137F.00  Read2
# 14    smoking    E251300  Read2
# 15    smoking    1371.11  Read2
# 16    smoking       1378  Read2
# 17    smoking       1371  Read2
# 18    smoking    137B.00  Read2
# 19    smoking    13WK.00  Read2
# 20    smoking    9kn..00  Read2
# 21    smoking        F17  ICD10
# 22    smoking       Z720  ICD10
# 23    smoking       Z716  ICD10
#
#                                           description                status  \
# ...

# %%
df_sel['vocab'].value_counts(dropna=False)
# Out:
# vocab
# Read2    21
# ICD10     3
# Name: count, dtype: int64

# %%
df_sel['status'].value_counts(dropna=False)
# Out:
# status
# Ex smoker               14
# Non smoker               5
# Current smoker           3
# Ex or current smoker     2
# Name: count, dtype: int64

# %%
# any CTV3?

df_read_new =  pd.merge(df_sel[(df_sel["vocab"]=="Read2") ], df_read_diff, on= ["code_clean"], how="inner")
df_read_new = df_read_new.drop(columns=["code_clean"])
df_read_new = df_read_new.rename(columns={"READ3":"code_clean"})
df_read_new["vocab"] = "Read3"

df_read_new.head()
# Out:
# Empty DataFrame
# Columns: [pheno_name, vocab, description, status, info, READV2_DESC, code_clean, TERMV3_DESC]
# Index: []

# %%
df_sel.to_csv(f'''{path}/smoking.csv''', index=False)
